% %%
l2errorP1 =[0.026669178876216;
0.0067063542743748;
0.0016790153921112;
0.00041990545869718;
0.0001049859512669]

ndofP1 =[
289; # ref3
1089;
4225;
16641;
66049
]
hP1 = 1.0./(sqrt(ndofP1) - ones(size(ndofP1)))


loglog(hP1,l2errorP1)
xlabel("Grid size")
ylabel("L2 error")
% Out:
% l2errorP1 =
%
%    0.02666918
%    0.00670635
%    0.00167902
%    0.00041991
%    0.00010499
%
% ndofP1 =
%
%      289
%     1089
%     4225
%    16641
%    66049
%
% hP1 =
%
%    0.0625000
%    0.0312500
%    0.0156250
%    0.0078125
%    0.0039062
%
% ndofP2 =
%
%     1089
%     4225
%    16641
%    66049
%
% hP2 =
%
%    0.0312500
%    0.0156250
%    0.0078125
%    0.0039062
%
% l2errorP2 =
%
%    0.0013023982
%    0.0001642214
%    0.0000205723
%    0.0000025729

% %%
ndofP2 =[
1089;# ref3
4225;
16641;
66049
]
hP2 = 1.0./(sqrt(ndofP2) - ones(size(ndofP2)))

l2errorP2 =[
0.0013023981752122;
0.00016422136810749;
2.0572340375291e-05;
2.5729390191579e-06
]
hold on
loglog(hP1,l2errorP1)
loglog(hP2,l2errorP2)
xlabel("Grid size")
ylabel("L2 error")
% Out:
% ndofP2 =
%
%     1089
%     4225
%    16641
%    66049
%
% hP2 =
%
%    0.0312500
%    0.0156250
%    0.0078125
%    0.0039062
%
% l2errorP2 =
%
%    0.0013023982
%    0.0001642214
%    0.0000205723
%    0.0000025729
